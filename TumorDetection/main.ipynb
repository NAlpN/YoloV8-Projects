# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR = '/content/gdrive/MyDrive/Colab Notebooks/yolov8/BrainTumorDetection/datasets'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 10.8 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8x-cls.pt')

results = model.train(data=DATA_DIR, epochs=75, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/classify/train2/weights/best.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/BrainTumorDetection/datasets/train/negative/0.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/BrainTumorDetection/datasets/train/negative/0.jpg: 64x64 negative 1.00, positive 0.00, 30.9ms
# Speed: 2.9ms preprocess, 30.9ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train2/weights/best.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/BrainTumorDetection/datasets/train/positive/10.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/BrainTumorDetection/datasets/train/positive/10.jpg: 64x64 positive 1.00, negative 0.00, 17.9ms
# Speed: 0.5ms preprocess, 17.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
