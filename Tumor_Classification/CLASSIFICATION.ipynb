# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks/yolov8/datasets'
# Out:
# train  train.cache  val  val.cache

# %%
DATA_DIR = '/content/gdrive/My Drive/Colab Notebooks/yolov8/datasets'

# %%
# !pip install ultralytics

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')

results = model.train(data=DATA_DIR, epochs=20, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/classify/train2/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/datasets/train/glioma_tumor/G_1.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/datasets/train/glioma_tumor/G_1.jpg: 64x64 glioma_tumor 0.83, meningioma_tumor 0.16, normal 0.01, pituitary_tumor 0.00, 12.1ms
# Speed: 1.3ms preprocess, 12.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
