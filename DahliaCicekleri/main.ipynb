# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR = '/content/gdrive/My Drive/Colab Notebooks/yolov8/DahliaCicekleri/dataset'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8x-cls.pt')

results = model.train(data=DATA_DIR, epochs=60, imgsz=64)
# Out:
# ...
# 100%|██████████| 110M/110M [00:01<00:00, 71.7MB/s]
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/DahliaCicekleri/dataset/test/Ball Dahlias/Image_105.JPG')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/DahliaCicekleri/dataset/test/Ball Dahlias/Image_105.JPG: 64x64 Ball Dahlias 1.00, Collarette Dahlias 0.00, Waterlily Dahlias 0.00, Anemone Dahlias 0.00, Cactus Dahlias 0.00, 19.9ms
# Speed: 1.0ms preprocess, 19.9ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/DahliaCicekleri/dataset/test/Cactus Dahlias/Image_115.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/DahliaCicekleri/dataset/test/Cactus Dahlias/Image_115.jpg: 64x64 Cactus Dahlias 0.91, Ball Dahlias 0.04, Anemone Dahlias 0.03, Collarette Dahlias 0.01, Waterlily Dahlias 0.01, 18.9ms
# Speed: 0.8ms preprocess, 18.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
