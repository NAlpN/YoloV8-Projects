# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import os

# %%
os.environ['KAGGLE_CONFIG_DIR'] = '/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19'

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19

# %%
# !kaggle datasets download -d pranavraikokte/covid19-image-dataset
# Out:
# ...
#  92% 145M/158M [00:01<00:00, 136MB/s]
# 100% 158M/158M [00:01<00:00, 109MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  covid19-image-dataset.zip
#   inflating: Covid19-dataset/test/Covid/0100.jpeg
#   inflating: Covid19-dataset/test/Covid/0102.jpeg
#   inflating: Covid19-dataset/test/Covid/0105.png
#   inflating: Covid19-dataset/test/Covid/0106.jpeg
#   inflating: Covid19-dataset/test/Covid/0108.jpeg
#   inflating: Covid19-dataset/test/Covid/0111.jpg
#   inflating: Covid19-dataset/test/Covid/0112.jpg
#   inflating: Covid19-dataset/test/Covid/0113.jpg
#   inflating: Covid19-dataset/test/Covid/0115.jpeg
#   inflating: Covid19-dataset/test/Covid/0118.jpeg
#   inflating: Covid19-dataset/test/Covid/0119.jpeg
#   inflating: Covid19-dataset/test/Covid/0120.jpg
#   inflating: Covid19-dataset/test/Covid/094.png
#   inflating: Covid19-dataset/test/Covid/096.png
#   inflating: Covid19-dataset/test/Covid/098.jpeg
#   inflating: Covid19-dataset/test/Covid/COVID-00003b.jpg
#   inflating: Covid19-dataset/test/Covid/COVID-00012.jpg
#   inflating: Covid19-dataset/test/Covid/COVID-00022.jpg
# ...

# %%
DATA_DIR = '/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8x-cls.pt')

results = model.train(data=DATA_DIR, epochs=100, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/runs/classify/train2/weights/best.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test1-Normal.jpeg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test1-Normal.jpeg: 64x64 Normal 1.00, Covid 0.00, Viral Pneumonia 0.00, 18.7ms
# Speed: 1.1ms preprocess, 18.7ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)

# %%
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/runs/classify/train2/weights/best.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test2-Covid.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test2-Covid.jpg: 64x64 Covid 1.00, Viral Pneumonia 0.00, Normal 0.00, 17.4ms
# Speed: 0.7ms preprocess, 17.4ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/runs/classify/train2/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test1-Normal.jpeg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test1-Normal.jpeg: 64x64 Normal 1.00, Covid 0.00, Viral Pneumonia 0.00, 25.1ms
# Speed: 0.8ms preprocess, 25.1ms inference, 6.9ms postprocess per image at shape (1, 3, 64, 64)

# %%
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/runs/classify/train2/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test2-Covid.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/Covid-19/datasets/test2-Covid.jpg: 64x64 Covid 1.00, Viral Pneumonia 0.00, Normal 0.00, 17.2ms
# Speed: 0.5ms preprocess, 17.2ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
