# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_DIR = '/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 6.9 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8x-cls.pt')

results = model.train(data=DATA_DIR, epochs=50, imgsz=64)
# Out:
# ...
# 100%|██████████| 110M/110M [00:00<00:00, 263MB/s]
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/My Drive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/other/6.jpg')
# Out:
# image 1/1 /content/gdrive/My Drive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/other/6.jpg: 64x64 other 1.00, spondylolisthesis 0.00, osteochondrosis 0.00, disability 0.00, scoliosis 0.00, 17.8ms
# Speed: 0.9ms preprocess, 17.8ms inference, 0.2ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/disability/2.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/disability/2.jpg: 64x64 disability 1.00, healthy 0.00, osteoporosis 0.00, other 0.00, spondylolisthesis 0.00, 17.9ms
# Speed: 0.8ms preprocess, 17.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/healthy/6.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/healthy/6.jpg: 64x64 healthy 1.00, osteochondrosis 0.00, scoliosis 0.00, osteoporosis 0.00, other 0.00, 17.9ms
# Speed: 0.7ms preprocess, 17.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/osteochondrosis/2.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/osteochondrosis/2.jpg: 64x64 osteochondrosis 1.00, scoliosis 0.00, osteoporosis 0.00, healthy 0.00, vertebral_compression_fracture 0.00, 18.1ms
# Speed: 0.7ms preprocess, 18.1ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/osteoporosis/4.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/osteoporosis/4.jpg: 64x64 osteoporosis 1.00, healthy 0.00, spondylolisthesis 0.00, other 0.00, osteochondrosis 0.00, 17.8ms
# Speed: 0.7ms preprocess, 17.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/scoliosis/4.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/scoliosis/4.jpg: 64x64 scoliosis 1.00, osteochondrosis 0.00, spondylolisthesis 0.00, osteoporosis 0.00, vertebral_compression_fracture 0.00, 19.9ms
# Speed: 0.8ms preprocess, 19.9ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/spondylolisthesis/6.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/spondylolisthesis/6.jpg: 64x64 spondylolisthesis 1.00, healthy 0.00, scoliosis 0.00, osteochondrosis 0.00, disability 0.00, 19.6ms
# Speed: 0.9ms preprocess, 19.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/vertebral_compression_fracture/9.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/OmurgaHastalikTespiti/datasets/test/vertebral_compression_fracture/9.jpg: 64x64 vertebral_compression_fracture 1.00, other 0.00, osteochondrosis 0.00, healthy 0.00, disability 0.00, 17.8ms
# Speed: 0.6ms preprocess, 17.8ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
