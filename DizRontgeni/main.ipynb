# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 7.5 MB/s eta 0:00:00
# ...

# %%
DATA_DIR = '/content/gdrive/MyDrive/Colab Notebooks/yolov8/DizRontgeni/datasets'

# %%
import os
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/Colab Notebooks/yolov8/DizRontgeni/yolov8l-cls.pt')

results = model.train(data=DATA_DIR, epochs=50, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.205 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/classify/train2/weights/best.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/DizRontgeni/datasets/test/stage_3/7.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/DizRontgeni/datasets/test/stage_3/7.jpg: 64x64 stage_3 0.96, stage_2 0.03, stage_1 0.01, stage_4 0.00, fracture 0.00, 14.7ms
# Speed: 0.9ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train2/weights/last.pt')

result = model('/content/gdrive/MyDrive/Colab Notebooks/yolov8/DizRontgeni/datasets/test/stage_1/1.jpg')
# Out:
# image 1/1 /content/gdrive/MyDrive/Colab Notebooks/yolov8/DizRontgeni/datasets/test/stage_1/1.jpg: 64x64 stage_1 1.00, stage_3 0.00, fracture 0.00, stage_4 0.00, arthritis 0.00, 14.7ms
# Speed: 0.7ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
