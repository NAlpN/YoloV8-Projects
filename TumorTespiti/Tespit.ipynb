# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks/yolov8/TumorTespiti/datasets'
# Out:
# train  train.cache  val  val.cache

# %%
DATA_DIR = '/content/gdrive/My Drive/Colab Notebooks/yolov8/TumorTespiti/datasets'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 10.9 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')

results = model.train(data=DATA_DIR, epochs=50, imgsz=64)
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/classify/train2/weights/last.pt')

result = model('/content/gdrive/My Drive/Colab Notebooks/yolov8/TumorTespiti/datasets/train/yes/Y259.JPG')
# Out:
# image 1/1 /content/gdrive/My Drive/Colab Notebooks/yolov8/TumorTespiti/datasets/train/yes/Y259.JPG: 64x64 yes 0.99, no 0.01, 4.6ms
# Speed: 0.7ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)

# %%
model = YOLO('/content/runs/classify/train2/weights/last.pt')

result = model('/content/gdrive/My Drive/Colab Notebooks/yolov8/TumorTespiti/datasets/train/no/No22.jpg')
# Out:
# image 1/1 /content/gdrive/My Drive/Colab Notebooks/yolov8/TumorTespiti/datasets/train/no/No22.jpg: 64x64 no 1.00, yes 0.00, 3.7ms
# Speed: 0.6ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 64, 64)
